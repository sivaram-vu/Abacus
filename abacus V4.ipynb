# %%
# !pip install emoji --upgrade

# %%
import abacus_lib
numbers = list(range(1, 10))

# %%
import abacus_lib
numbers = list(range(10, 100, 10))

# %%
import abacus_lib
numbers = list(range(1, 100))

# %%
abacus_lib.plot_next(numbers)
# Out:
# Hi there! 👍
